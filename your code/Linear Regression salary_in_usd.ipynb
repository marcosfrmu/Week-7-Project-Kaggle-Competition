# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/mfran/Downloads/ds_salaries.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
data.head(15)
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 0            0       2020               MI              FT
# 1            1       2020               SE              FT
# 2            2       2020               SE              FT
# 3            3       2020               MI              FT
# 4            4       2020               SE              FT
# 5            5       2020               EN              FT
# 6            6       2020               SE              FT
# 7            7       2020               MI              FT
# 8            8       2020               MI              FT
# 9            9       2020               SE              FT
# 10          10       2020               EN              FT
# 11          11       2020               MI              FT
# 12          12       2020               EN              FT
# 13          13       2020               MI              FT
# 14          14       2020               MI              FT
#
#                      job_title    salary salary_currency  salary_in_usd  \
# 0               Data Scientist     70000             EUR          79833
# 1   Machine Learning Scientist    260000             USD         260000
# 2            Big Data Engineer     85000             GBP         109024
# 3         Product Data Analyst     20000             USD          20000
# 4    Machine Learning Engineer    150000             USD         150000
# 5                 Data Analyst     72000             USD          72000
# 6          Lead Data Scientist    190000             USD         190000
# 7               Data Scientist  11000000             HUF          35735
# 8        Business Data Analyst    135000             USD         135000
# 9           Lead Data Engineer    125000             USD         125000
# 10              Data Scientist     45000             EUR          51321
# 11              Data Scientist   3000000             INR          40481
# 12              Data Scientist     35000             EUR          39916
# 13           Lead Data Analyst     87000             USD          87000
# 14                Data Analyst     85000             USD          85000
#
#    employee_residence  remote_ratio company_location company_size
# 0                  DE             0               DE            L
# 1                  JP             0               JP            S
# 2                  GB            50               GB            M
# 3                  HN             0               HN            S
# 4                  US            50               US            L
# 5                  US           100               US            L
# 6                  US           100               US            S
# 7                  HU            50               HU            L
# 8                  US           100               US            L
# 9                  NZ            50               NZ            S
# 10                 FR             0               FR            S
# 11                 IN             0               IN            L
# 12                 FR             0               FR            M
# 13                 US           100               US            L
# 14                 US           100               US            L

# %%
data.shape
# Out:
# (607, 12)

# %%
data.plot("salary_in_usd")
# Out:
# <AxesSubplot:xlabel='salary_in_usd'>

# %%
X=pd.get_dummies(data,columns=['employment_type','experience_level'],drop_first=True) 

X.head()
# Out:
#    Unnamed: 0  work_year                   job_title  salary salary_currency  \
# 0           0       2020              Data Scientist   70000             EUR
# 1           1       2020  Machine Learning Scientist  260000             USD
# 2           2       2020           Big Data Engineer   85000             GBP
# 3           3       2020        Product Data Analyst   20000             USD
# 4           4       2020   Machine Learning Engineer  150000             USD
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          79833                 DE             0               DE
# 1         260000                 JP             0               JP
# 2         109024                 GB            50               GB
# 3          20000                 HN             0               HN
# 4         150000                 US            50               US
#
#   company_size  employment_type_FL  employment_type_FT  employment_type_PT  \
# 0            L                   0                   1                   0
# 1            S                   0                   1                   0
# 2            M                   0                   1                   0
# 3            S                   0                   1                   0
# 4            L                   0                   1                   0
#
#    experience_level_EX  experience_level_MI  experience_level_SE
# 0                    0                    1                    0
# 1                    0                    0                    1
# 2                    0                    0                    1
# 3                    0                    1                    0
# 4                    0                    0                    1

# %%
x=X.select_dtypes(exclude='object')

# %%
x
# Out:
#      Unnamed: 0  work_year  salary  salary_in_usd  remote_ratio  \
# 0             0       2020   70000          79833             0
# 1             1       2020  260000         260000             0
# 2             2       2020   85000         109024            50
# 3             3       2020   20000          20000             0
# 4             4       2020  150000         150000            50
# ..          ...        ...     ...            ...           ...
# 602         602       2022  154000         154000           100
# 603         603       2022  126000         126000           100
# 604         604       2022  129000         129000             0
# 605         605       2022  150000         150000           100
# 606         606       2022  200000         200000           100
#
#      employment_type_FL  employment_type_FT  employment_type_PT  \
# 0                     0                   1                   0
# 1                     0                   1                   0
# 2                     0                   1                   0
# 3                     0                   1                   0
# 4                     0                   1                   0
# ..                  ...                 ...                 ...
# 602                   0                   1                   0
# 603                   0                   1                   0
# 604                   0                   1                   0
# 605                   0                   1                   0
# 606                   0                   1                   0
#
#      experience_level_EX  experience_level_MI  experience_level_SE
# 0                      0                    1                    0
# 1                      0                    0                    1
# 2                      0                    0                    1
# 3                      0                    1                    0
# 4                      0                    0                    1
# ..                   ...                  ...                  ...
# 602                    0                    0                    1
# 603                    0                    0                    1
# 604                    0                    0                    1
# 605                    0                    0                    1
# 606                    0                    1                    0
#
# [607 rows x 11 columns]

# %%
x.reset_index(drop=True,inplace=True)
data_train=x.loc[0:499]

# %%
data_test=x.loc[500:].drop(['salary_in_usd'],axis=1)

# %%
data_train
# Out:
#      Unnamed: 0  work_year  salary  salary_in_usd  remote_ratio  \
# 0             0       2020   70000          79833             0
# 1             1       2020  260000         260000             0
# 2             2       2020   85000         109024            50
# 3             3       2020   20000          20000             0
# 4             4       2020  150000         150000            50
# ..          ...        ...     ...            ...           ...
# 495         495       2022  153000         153000            50
# 496         496       2022   52800          58035           100
# 497         497       2022  165000         165000           100
# 498         498       2022   85000          93427            50
# 499         499       2022   66500          52396           100
#
#      employment_type_FL  employment_type_FT  employment_type_PT  \
# 0                     0                   1                   0
# 1                     0                   1                   0
# 2                     0                   1                   0
# 3                     0                   1                   0
# 4                     0                   1                   0
# ..                  ...                 ...                 ...
# 495                   0                   1                   0
# 496                   0                   1                   0
# 497                   0                   1                   0
# 498                   0                   1                   0
# 499                   0                   1                   0
#
#      experience_level_EX  experience_level_MI  experience_level_SE
# 0                      0                    1                    0
# 1                      0                    0                    1
# 2                      0                    0                    1
# 3                      0                    1                    0
# 4                      0                    0                    1
# ..                   ...                  ...                  ...
# 495                    0                    1                    0
# 496                    0                    0                    0
# 497                    0                    0                    1
# 498                    0                    0                    1
# 499                    0                    0                    0
#
# [500 rows x 11 columns]

# %%
X=data_train.drop(['salary_in_usd'],axis=1)
y=data_train['salary_in_usd']

# %%
y
# Out:
# 0       79833
# 1      260000
# 2      109024
# 3       20000
# 4      150000
#         ...
# 495    153000
# 496     58035
# 497    165000
# 498     93427
# 499     52396
# Name: salary_in_usd, Length: 500, dtype: int64

# %%
from sklearn.model_selection import train_test_split as tts 

X_train, X_test, y_train, y_test = tts(X, y, train_size=0.8, test_size=0.2, random_state=22)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 10), (100, 10), (400,), (100,))

# %%
from sklearn.linear_model import LinearRegression as LinReg
linreg=LinReg()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(X_test)
y_pred.max()
# Out:
# 266956.7612134814

# %%
from sklearn.metrics import mean_squared_error as mse  
y_pred=linreg.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 61854.86584499803

# %%
y_pred
# Out:
# array([ 89849.49907596, 147573.49536279,  90214.77259068, 139467.83687775,
#         90786.47079648,   9707.69108047,  93046.57019395, 127829.67367044,
#        144215.76283114, 150173.04355641, 121416.25052994, 142930.55430634,
#         89671.03797941, 142721.31609994,  68993.09942377, 138577.57620851,
#         87218.37146785, 143258.28611705, 266956.76121348,  93765.63097516,
#         96466.81428382, 129491.55744306,  89055.98758795, 204072.98846103,
#        143986.72256117, 143547.75291342,  50808.35762218, 127805.9490058 ,
#         90239.76028101,  84160.02945263, 145025.47118734, 188342.16082852,
#         89497.38492497,  83755.58531768,  59266.30400422,  59521.50956394,
#        140971.13610337, 140122.08957336,  77101.72884533,  78666.52948414,
#         76574.12174193,   8328.05924835, 137617.99206804,  86795.60315342,
#        141079.70598764, 140667.81932473, 145626.23346669,  91323.67214683,
#         86821.93050941,  51060.38773897,  90353.52295657,  95681.51089229,
#         90375.67637119, 144356.96591134, 141114.47471446, 143967.43586294,
#        203232.00763669,  74408.26057352,  62990.75127999,  84040.41541286,
#        141571.53644612, 139541.59488406,  35034.32410356,  52531.80682155,
#        128853.2287364 , 139549.84179427, 135290.18123858,  64198.82926445,
#         57111.29379554, 121909.3604623 ,  84651.71014353, 140408.22771476,
#         56987.53035107,  86324.68301041,  28890.82400808, 194243.14092763,
#        128815.73702491,  86586.66520286, 140277.9284252 , 202394.06772686,
#        198916.51435886,  58065.51247571,  89794.16453043, 143972.40544727,
#         83499.0441485 , 144146.44858446, 141518.43871353,  90227.18129293,
#        142818.5697707 , 141290.67076223, 131643.0390457 , 144313.78401151,
#        141402.5796115 ,  64936.98206988,  88713.19196475,  63014.45959874,
#        128239.71693201, 200502.78992563, 140416.48469236,  74667.54895276])

# %%
residuals = y_pred - y_test

# %%
plt.hist(residuals)
# Out:
# (array([ 1.,  0.,  0.,  1.,  4., 10., 29., 40., 13.,  2.]),
#  array([-338959.58458714, -288867.95000708, -238776.31542702,
#         -188684.68084695, -138593.04626689,  -88501.41168683,
#          -38409.77710677,   11681.85747329,   61773.49205336,
#          111865.12663342,  161956.76121348]),
#  <BarContainer object of 10 artists>)
